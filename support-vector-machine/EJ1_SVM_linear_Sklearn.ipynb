# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# %%
# Features
X = np.array([
  [-1,0], # Negatives
  [0,-1], # Negatives
  [0,1],  # Negatives
  [1,0],  # Negatives <-- Support nº1
  
  [3,1],  # Positives <-- Support nº2
  [3,-1], # Positives <-- Support nº3
  [6,1],  # Positives
  [6,-1]  # Positives
])

# %%
# Labels
y = np.array([-1, -1, -1, -1, 1, 1, 1, 1])

# %%
clf = svm.SVC(kernel='linear').fit(X, y)

# %%
clf.predict([[5,2]])
# Out:
# array([1])

# %%
# Plotting the decision boundary and support vectors
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, marker='o')

# Plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# Create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100, linewidth=1, facecolors='none', edgecolors='k')

plt.show()

# %%
coef = clf.coef_[0] # Coefficients of the decision function
intercept = clf.intercept_[0] # Intercept of the decision function

print("y =", intercept, "+", coef[0], "* x1 +", coef[1], "* x2")
# Out:
# y = -2.0004480000000004 + 1.0001920000000002 * x1 + -0.00038400000000038403 * x2
